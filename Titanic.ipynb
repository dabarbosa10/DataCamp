# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

#data=pd.read_csv('/Users/diegobarbosa/Documents/WorksPace/DataCamp/titanic3.csv')

# %%
data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
data['age'].hist()
plt.xlabel('Age')
plt.ylabel('Number')
plt.show()

# %%
data.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
data['age'].fillna(data['age'].median())
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305    28.00
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
data.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
data['age'].hist()
plt.xlabel('Age')
plt.ylabel('Number')
plt.show()

# %%
import seaborn as sns

# %%
fig,axs=plt.subplots(ncols=5,figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
mapping={'female':0, 'male':1}
data['sex']=data['sex'].replace(mapping)
# Out:
# /var/folders/1q/0hxf4fzj2jbglfwkb_9dr8680000gn/T/ipykernel_844/1025414034.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['sex']=data['sex'].replace(mapping)

# %%
data['sex'].value_counts(normalize=True).plot.bar(title='Sex')
# Out:
# <Axes: title={'center': 'Sex'}, xlabel='sex'>

# %%
numeric_data=data.select_dtypes(include='number')
matrix=numeric_data.corr()
sns.heatmap(matrix,vmax=0.8, square=True, cmap='BuPu')
# Out:
# <Axes: >

# %%
data.corr(numeric_only=True).abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
correlation=data['survived'].corr(data['sex'])
print(f'Correlation between variables is {correlation}')
# Out:
# Correlation between variables is -0.5286930913889885
